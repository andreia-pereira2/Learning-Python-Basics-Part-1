# %% [markdown]
# # Why Data Analyst Needs Python?

# %% [markdown]
# Learning Python provides several practical benefits for data analysts. Let's explore some of them:
#
# 1. **Versatility and Popularity**:
#    - Python is a widely used programming language in the data science and analytics community.
#    - It's versatile, making it suitable for various tasks, including data manipulation, visualization, and machine learning.
#    - Its popularity ensures a wealth of resources, libraries, and community support.
#
# 2. **Rich Ecosystem of Libraries**:
#    - Python has powerful libraries such as **pandas**, **NumPy**, and **matplotlib** that simplify data manipulation, analysis, and visualization.
#    - **pandas** allows efficient handling of structured data (e.g., CSV files, databases).
#    - **NumPy** provides essential numerical operations for scientific computing.
#    - **matplotlib** enables creating visualizations.
#
# 3. **Ease of Learning and Readability**:
#    - Python has a clean and readable syntax, making it accessible for beginners.
#    - Data analysts can quickly learn and write code, even without extensive programming experience.
#
# 4. **Data Cleaning and Preprocessing**:
#    - Python excels in data cleaning and preprocessing tasks.
#    - Analysts can handle missing values, outliers, and inconsistencies efficiently using Python libraries.
#
# 5. **Statistical Analysis and Hypothesis Testing**:
#    - Python supports statistical analysis, hypothesis testing, and regression modeling.
#    - Libraries like **statsmodels** and **scipy** provide tools for these tasks.
#
# 6. **Data Visualization**:
#    - Python libraries (e.g., **matplotlib**, **seaborn**, and **plotly**) allow analysts to create informative visualizations.
#    - Communicating insights through charts, graphs, and plots is crucial for decision-makers.
#
# 7. **Machine Learning and Predictive Modeling**:
#    - Python integrates seamlessly with machine learning libraries such as **scikit-learn** and **TensorFlow**.
#    - Analysts can build predictive models, classify data, and perform clustering.
#
# 8. **Integration with Big Data Tools**:
#    - Python interfaces well with big data tools like **Apache Spark** and **Hadoop**.
#    - Analysts can process large datasets efficiently.
#
# 9. **Collaboration and Communication**:
#    - Python code is readable and easy to share.
#    - Collaborating with other analysts and stakeholders becomes smoother.
#
# 10. **Career Opportunities**:
#     - Proficiency in Python enhances job prospects.
#     - Data analysts with Python skills are in high demand across industries.
#
# In summary, learning Python empowers data analysts to extract insights, make informed decisions, and contribute effectively to data-driven organizations. 🐍📊
#
# Sources:
# (1) Using Python for Data Analysis – Real Python. https://realpython.com/python-for-data-analysis/.
#
# (2) Python for Data Analysis - Career Karma. https://careerkarma.com/blog/python-for-data-analysis-tutorial/.
#
# (3) Why Do Data Analysts Use Python? | UCD Professional Academy. https://www.ucd.ie/professionalacademy/resources/why-do-data-analysts-use-python/.
#
# (4) Why use Python for Data Analysis - The Python Code. https://thepythoncode.com/article/why-use-python-for-data-analysis.
#
# (5) en.wikipedia.org. https://en.wikipedia.org/wiki/Python_(programming_language).

# %% [markdown]
# # Python Basics

# %% [markdown]
# ## Is Python Installed on Google Colab?

# %%
# this is how you check for the python version
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# ## Accessing Help for Python in Colab
#
# Google Colab provides several ways to access Python help and documentation directly within the environment. Here are the different methods you can use:
#
# ### 1. Using the Help Menu
#
# - **Help Documentation**: The Help menu in the top toolbar of Google Colab provides access to various resources, including documentation and tutorials.
#   - Click on **Help** in the menu bar and select **Welcome to Colaboratory!** to access a helpful overview of Colab features.
#   - Select **Python documentation** to be directed to the official Python documentation.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %% [markdown]
# ### 2. Inline Help with `help()` Function
#
# - **Using `help()` Function**: You can use the built-in `help()` function to get information about functions, modules, and objects.
#
# ```python
# help(str)  # Get help on the string class
# help(len)  # Get help on the len() function
# ```

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# ### 3. Using `?` and `??` Operators
#
# - **Single Question Mark (`?`)**: Placing a question mark before or after a function, class, or variable will display a short help message or docstring.
#
# ```python
# len?  # Display the docstring of the len() function
# ```
#
# - **Double Question Marks (`??`)**: Placing double question marks will provide more detailed information, including the source code if available.
#
# ```python
# len??  # Display detailed information about the len() function
# ```

# %%
len?

# %%
len??

# %%
min?

# %% [markdown]
# ### 4. Tooltips and Autocompletion
#
# - **Tooltips**: When writing code, if you pause after typing an open parenthesis `(` following a function or class name, Colab will display a tooltip showing the function signature and docstring.
#
# ```python
# len(  # Pause after typing the open parenthesis to see the tooltip
# ```
#
# - **Autocompletion**: Press `Tab` after typing the beginning of a function or method name to see a list of possible completions and their docstrings.

# %% [markdown]
# ### 5. Documentation in Markdown Cells
#
# - **Markdown Cells**: You can write documentation and notes using Markdown cells within your notebook. This is useful for creating tutorials and explanatory text alongside your code.

# %% [markdown]
# ### 6. Google Colab FAQs and Community
#
# - **Colab FAQs**: Access frequently asked questions and troubleshooting guides from the Help menu.
#   - Click on **Help** and select **FAQ**.
#
# - **Community Forums**: You can ask questions and seek help from the Colab community through forums such as Stack Overflow.

# %% [markdown]
# # Let's Mount the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # print() function displays.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
print('single')
# Out:
# single

# %%
print(20+20)
# Out:
# 40

# %%
print("20+20")
# Out:
# 20+20

# %%
20 + 20
# Out:
# 40

# %%
print("age 20")
# Out:
# age 20

# %%
print("I am learning Python.')
# Out:
#   File "<ipython-input-27-5621dbbf77d8>", line 1
#     print("I am learning Python.')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("3.14")
print(type("3.14"))
print(3.14)
print(type(3.14))
# Out:
# 3.14
# <class 'str'>
# 3.14
# <class 'float'>

# %%
print("3.14" * 2)
print(3.14 * 2)
# Out:
# 3.143.14
# 6.28

# %%
#what is a function?
function(prameters or arguments).subfunction()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b5a74015399e> in <cell line: 0>()
#       1 #what is a function?
# ----> 2 function(prameters or arguments).subfunction()
#
# NameError: name 'function' is not defined

# %%
#a function without any argument
print()

# %%
print(print)
# Out:
# <built-in function print>

# %%
#Using type()
type(print)
# Out:
# builtin_function_or_method

# %%
# ?type

# %%
type(4)
# Out:
# int

# %%
print(type(print))
# Out:
# <class 'builtin_function_or_method'>

# %%
print("print")
# Out:
# print

# %% [markdown]
# ### You can use "" or '' in your code. But choose one and stick to it.
# ### You can not use " and ' together.

# %%
print("Hello World!')
# Out:
#   File "<ipython-input-39-90700430ebea>", line 1
#     print("Hello World!')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello World!")
# Out:
#   File "<ipython-input-40-b3b4c1299fc6>", line 1
#     print('Hello World!")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(15)
# Out:
# 15

# %%
print("15")
# Out:
# 15

# %% [markdown]
# ## Over to you - Lab - Exercise
# **Estimated time**
# 5-10 minutes
#
# **Objectives**
# becoming familiar with the print() function and its formatting capabilities;
# experimenting with Python code.
#
# **Scenario**
# The print() command, which is one of the easiest directives in Python, simply prints out a line to the screen.
#
# **In your first lab:**
#
#
#
# 1. use the print() function to print the line Hello, Python! to the screen.Use
# double quotes around the string;
# 2. having done that, use the print() function again, but this time print your first name;
# 3. remove the double quotes and run your code. Watch Python's reaction. What kind of error is thrown?
# 4. then, remove the parentheses, put back the double quotes, and run your code again. What kind of error is thrown this time?
# 5. experiment as much as you can. Change double quotes to single quotes, use multiple print() functions on the same line, and then on different lines. See what happens.

# %% [markdown]
# ## Solution
#
# 1. Use the print() function to print the line Hello, Python! to the screen. Use double quotes around the string.
#
# `print("Hello, Python!")`
#
#
# 2. Having done that, use the print() function again, but this time print your first name.
#
#
# ```
# print("Hello, Python!")
# print("John")
# ```
#
# 3. Remove the double quotes and run your code. Watch Python’s reaction. What kind of error is thrown?
#
# If you remove the double quotes, Python will throw a SyntaxError because it expects a string literal to be enclosed in quotes.
#
# 4. Then, remove the parentheses, put back the double quotes, and run your code again. What kind of error is thrown this time?
#
# If you remove the parentheses, Python will throw a TypeError because it expects a function call.
#
# 5. Experiment as much as you can. Change double quotes to single quotes, use multiple print() functions on the same line, and then on different lines. See what happens.
#
#
# You can use either single or double quotes to enclose a string literal. If you use single quotes, make sure that the string does not contain any single quotes, or else you will need to escape them using a backslash. Here are some examples:
#
#
# ```
# print('Hello, Python!')
# print('John')
# print("Hello, Python!", "John")
# print('Hello, Python!\nJohn')
# ```
#
#
# The first two examples print a single string literal on a separate line. The third example prints two string literals on the same line, separated by a space. The fourth example prints a string literal with a newline character followed by another string literal on separate lines.

# %% [markdown]
# # Whats the differnce between these syntax?

# %%
print("3.14")
# Out:
# 3.14

# %%
print(3.14)
# Out:
# 3.14

# %% [markdown]
# Same output?

# %% [markdown]
# ### `type()` function displays type of data

# %%
print(type("3.14"))
# Out:
# <class 'str'>

# %%
type("3.14")
# Out:
# str

# %%
print(type(3.14))
# Out:
# <class 'float'>

# %%
print(type(50))
# Out:
# <class 'int'>

# %%
print(type("50"))
# Out:
# <class 'str'>

# %%
print(type(0))
# Out:
# <class 'int'>

# %% [markdown]
# True and False Boolean Data Type

# %%
print(type(True))
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ### Python is case sensitive. False is not the same as false

# %%
print(type(false))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-8f67c18c10ca> in <cell line: 0>()
# ----> 1 print(type(false))
#
# NameError: name 'false' is not defined

# %%
print(type(False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-a7c8cad68623> in <cell line: 0>()
# ----> 1 Print(type(False))
#
# NameError: name 'Print' is not defined

# %%
print(type(False))
# Out:
# <class 'bool'>

# %% [markdown]
# ## Escape characters

# %%
print('My father's car is red.')
# Out:
#   File "<ipython-input-58-487aadbe37ad>", line 1
#     print('My father's car is red.')
#                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("My father's car is red.")
# Out:
# My father's car is red.

# %%
print()

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.\n\n")

print()
print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.
#
#
#
# Down came the rain
# and washed the spider out.

# %%
print("The itsy bitsy spider")
print("climbed up the waterspout.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.

# %%
print("The itsy bitsy spider\climbed up the waterspout.")
# Out:
# The itsy bitsy spider\climbed up the waterspout.

# %%
print("The itsy bitsy spiderclimbed up the waterspout.\t213")
# Out:
# The itsy bitsy spiderclimbed up the waterspout.	213

# %%
print("The itsy bitsy spiderclimbed up the waterspout.\,213")
# Out:
# The itsy bitsy spiderclimbed up the waterspout.\,213

# %%
print("\")
# Out:
#   File "<ipython-input-79-dff1232de400>", line 1
#     print("\")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Not allowed to use single \ without any other character

# %%
print("\\")
# Out:
# \

# %%
print("The itsy bitsy spider\\nclimbed up the waterspout.")
print()
print("Down came the rain\\nand washed the spider out.")
# Out:
# The itsy bitsy spider\nclimbed up the waterspout.
#
# Down came the rain\nand washed the spider out.

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")

print()

print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.
#
# Down came the rain
# and washed the spider out.

# %%
print("The itsy bitsy spider\n\nclimbed up the waterspout.")
print()
print("Down came the rain\n\nand washed the spider out.")
# Out:
# The itsy bitsy spider
#
# climbed up the waterspout.
#
# Down came the rain
#
# and washed the spider out.

# %% [markdown]
# ### \' Single Quote Escape Character

# %%
print('My brother's birthday is 18th July.')
# Out:
#   File "<ipython-input-85-fd681313ce92>", line 1
#     print('My brother's birthday is 18th July.')
#                                      ^
# SyntaxError: invalid decimal literal

# %%
print('My brother\'s birthday is 18th July.')
# Out:
# My brother's birthday is 18th July.

# %%
print("My brother's birthday is 18th July.")
# Out:
# My brother's birthday is 18th July.

# %%
print("My brother\'s birthday is 18th July.")
# Out:
# My brother's birthday is 18th July.

# %% [markdown]
# ### \t Tab

# %%
print("I have a red car.")
# Out:
# I have a red car.

# %%
print("I have \t a red car.")
# Out:
# I have 	 a red car.

# %%
print("I have    a red car.")
# Out:
# I have    a red car.

# %%
print("Hello,\n pearl \rfirst word is overwritten")
# Out:
# Hello,
# first word is overwritten

# %% [markdown]
# ###You can try the whoe list of other escape characters here - Optional
#
# | Code  | Result          | Try it                                                                                    |
# | ----- | --------------- | ----------------------------------------------------------------------------------------- |
# | \\'   | Single Quote    | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_string_escape2)   |
# | \\\\  | Backslash       | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_string_backslash) |
# | \\n   | New Line        | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_string_newline)   |
# | \\r   | Carriage Return | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_string_r)         |
# | \\t   | Tab             | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_string_t)         |
# | \\b   | Backspace       | [Try it »](https://www.w3schools.com/python/showpython.asp?filename=demo_string_b)        |
# | \\f   | Form Feed       |                                                                                           |
# | \\ooo | Octal value     | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_string_octal)     |
# | \\xhh | Hex value       | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_string_hex)       |

# %%
# form feeds are supposd to start from next page. rare to use these days but useful in text processing.

print("This is the first page.\fThis is the second page.")
# Out:
# This is the first page.This is the second page.

# %% [markdown]
# ## The print() function - using multiple arguments
# So far we have tested the `print()` function behavior with no arguments, and with one argument. It's also worth trying to feed the `print()` function with more than one argument.
#
# Look at the editor window. This is what we're going to test now:
#
# `print("The itsy bitsy spider" , "climbed up" , "the waterspout.")`
#
#
# There is one `print()` function invocation, but it contains **three arguments**. All of them are strings.
#
# The arguments are **separated by commas**. We've surrounded them with spaces to make them more visible, but it's not really necessary, and we won't be doing it anymore.
#
# In this case, the commas separating the arguments play a completely different role than the comma inside the string. The former is a part of Python's syntax, the latter is intended to be shown in the console.
#
# If you look at the code again, you'll see that there are no spaces inside the strings.
#
# Run the code and see what happens.
#
# The console should now be showing the following text:
#
# `The itsy bitsy spider climbed up the waterspout.`
#
# The spaces, removed from the strings, have appeared again. Can you explain why?
#
# **Two conclusions emerge from this example:**
#
# 1. a `print()` function invoked with more than one argument outputs them all on one line;
# 2. the `print()` function puts a space between the outputted arguments on its own initiative.

# %%
print("The itsy bitsy spider" ,          "climbed up" , "the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
print("The itsy bitsy spider climbed up the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
print("The itsy bitsy spider            " , "climbed up " , "the waterspout.")
# Out:
# The itsy bitsy spider             climbed up  the waterspout.

# %%
print("The result of", "2*3", "is", 6, ".",  "This is", True)
# Out:
# The result of 2*3 is 6 . This is True

# %%
# is python really space sensitive?
print("The itsy bitsy spider            " ,                                      "climbed up " , "the waterspout.")
# Out:
# The itsy bitsy spider             climbed up  the waterspout.

# %% [markdown]
# ## Arguments of print()

# %%
print("The itsy bitsy spider" , "climbed up" , "the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
print("The itsy bitsy spider","climbed up","the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
print("The itsy bitsy spider","climbed up",      "the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
print("The itsy bitsy spider","climbed up","the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
print("My name is", 'Python.')
print("Monty Python.")
# Out:
# My name is Python.
# Monty Python.

# %%
#concatenation
print("The itsy bitsy spider" + "climbed up" + "the waterspout.")
# Out:
# The itsy bitsy spiderclimbed upthe waterspout.

# %%
print("The itsy bitsy spider","climbed up","the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
#notice the spacing
#concatenation
print("The itsy bitsy spider" + "climbed up" + "the waterspout.")
# Out:
# The itsy bitsy spiderclimbed upthe waterspout.

# %%
print("2" + "2")
print(2+2)
# Out:
# 22
# 4

# %%
print("2 " + "2")
print("2" + " 2")
print("2"+ " " + "2")
# Out:
# 2 2
# 2 2
# 2 2

# %%
print("2", "a", "2")
print("2", "a", "2", sep="*")
print("2", "a", "2", sep="5")
print( "2", "a", "2", sep = "5")
# Out:
# 2 a 2
# 2*a*2
# 25a52
# 25a52

# %%
print("2", "a", "2", end=".")
# Out:
# 2 a 2.

# %%
print("2", "a", "2", end="\n")
print("2", "a", "2", sep = "*", end="_")
# Out:
# 2 a 2
# 2*a*2_

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# ## The `print()` function - the keyword arguments `end=`
# Python offers another mechanism for the passing of arguments, which can be helpful when you want to convince the `print() `function to change its behavior a bit.
#
# We aren't going to explain it in depth right now. We plan to do this when we talk about functions. For now, we simply want to show you how it works. Feel free to use it in your own programs.
#
# The mechanism is called keyword arguments. The name stems from the fact that the meaning of these arguments is taken not from its location (position) but from the special word (keyword) used to identify them.
#
# The `print()` function has two keyword arguments that you can use for your purposes. The first of them is named `end.`
#
# In the editor window you can see a very simple example of using a keyword argument.
#
# Make sure that you have a `,` before `end` argument. In order to use it, it is necessary to know some rules:
#
# * a keyword argument consists of three elements:
#   1. a keyword identifying the argument (`end `here);
#   2. an **equal sign** `(=)`;
#   3. and a **value** assigned to that argument;
# * any keyword arguments have to be put **after the last positional argument** (this is very important)
#
#
# In Python, the `end` parameter in the `print()` function allows you to customize the behavior of the output. By default, `print()` automatically inserts a newline character after each execution, which results in printing each item on a new line. However, using the `end` parameter, you can change this behavior.
#
# Here are some key points about the `end` parameter in `print()`:
#
# 1. **Default Behavior**:
#    - By default, `print()` ends with a newline character (`\n`), which moves the cursor to the next line after printing.
#    - For example:
#      ```python
#      print("Hello")
#      print("World")
#      # Output:
#      # Hello
#      # World
#      ```
#
# 2. **Customizing the End Character**:
#    - You can specify a different character or string to be used as the end character instead of the newline.
#    - For instance:
#      ```python
#      print("Welcome to", end=' ')
#      print("GeeksforGeeks", end=' ')
#      # Output: Welcome to GeeksforGeeks
#      ```
#
# 3. **Concatenating Strings**:
#    - You can use the `end` parameter to concatenate multiple `print()` statements into a single line of output.
#    - Example:
#      ```python
#      name = "Alice"
#      age = 30
#      print("My name is", name, "and I am", age, "years old.", end=" ")
#      print("Nice to meet you!")
#      # Output: My name is Alice and I am 30 years old. Nice to meet you!
#      ```
#
# 4. **Other Uses**:
#    - The `end` parameter is a useful feature for controlling the formatting of output in various ways.
#    - It allows you to customize how items are separated and whether they end with a newline or a different character.
#
# Remember, the `end` parameter provides flexibility in shaping your output, making it a handy tool for Python developers! 🐍👍
#
# In our example, we have made use of the `end` keyword argument, and set it to a string containing two spaces.
#
# Run the code to see how it works.

# %%
print("Welcome to", end=" ")
print("GeeksforGeeks", end=' ')
# Out:
# Welcome to GeeksforGeeks

# %%
name = "Alice"
age = 30
print("My name is", name, "and I am", age, "years old.", end=" ")
print("Nice to meet you!")
# Output: My name is Alice and I am 30 years old. Nice to meet you!
# Out:
# My name is Alice and I am 30 years old. Nice to meet you!

# %%
name = "Alice"
age = 30
print("My name is", name, "and I am", age, "years old.", end="--")
print("Nice to meet you!")
# Output: My name is Alice and I am 30 years old. Nice to meet you!
# Out:
# My name is Alice and I am 30 years old.--Nice to meet you!

# %%
#without the end="" argument
name = "Alice"
age = 30
print("My name is", name, "and I am", age, "years old.")
print("Nice to meet you!")
# Output: My name is Alice and I am 30 years old. Nice to meet you!
# Out:
# My name is Alice and I am 30 years old.
# Nice to meet you!

# %%
name1 = "Ali"
age = 30
print("My name is", name1, "and I am", age, "years old.", end=" ")
print("Nice to meet you!")
# Output: My name is Alice and I am 30 years old. Nice to meet you!
# Out:
# My name is Ali and I am 30 years old. Nice to meet you!

# %%
print("My name is", "Python.", end="     ------        ")
print("Monty Python.")
# Out:
# My name is Python.     ------        Monty Python.

# %% [markdown]
# The console should now be showing the following text:
#
# `My name is Python. Monty Python.`
#
#
# As you can see, the end keyword argument determines the characters the print() function sends to the output once it reaches the end of its positional arguments.
#
# The default behavior reflects the situation where the `end` keyword argument is implicitly used in the following way: `end="\n"`.

# %%
print("My name is", "Python.", end="--")
print("Monty Python.")
# Out:
# My name is Python.--Monty Python.

# %%
print("My name is", "Python.", end="")
print("Monty Python.")
# Out:
# My name is Python.Monty Python.

# %%
print("My name is", "Python.", end="\n")
print("Monty Python.")
print("Yulia.")
# Out:
# My name is Python.
# Monty Python.
# Yulia.

# %% [raw]
# ## The print() function - the keyword arguments
#
# ---
#
#
#
# And now it's time to try something more difficult.
#
# If you look carefully, you'll see that we've used the `end` argument, but the string assigned to it is empty (it contains no characters at all).
#
# What will happen now? Run the program in the editor to find out.
#
# As the `end` argument has been set to nothing, the `print()` function outputs nothing too, once its positional arguments have been exhausted.
#
# The console should now be showing the following text:
#
# `My name is Monty Python.`
#
#
# Note: **no newlines have been sent to the output.**
#
# The string assigned to the `end` keyword argument can be of any length. Experiment with it if you want.

# %%
print("My name is ", end="")
print("Monty Python.")
# Out:
# My name is Monty Python.

# %%
print("My name is ")
print("Monty Python.")
# Out:
# My name is
# Monty Python.

# %% [markdown]
# ## The `print()` function - the keyword arguments `sep=`
#
# We've said previously that the `print()` function separates its outputted arguments with spaces. This behavior can be changed, too.
#
# The **keyword argument** that can do this is named `sep` (like separator).
#
# In Python, the `sep` parameter in the `print()` function allows you to **customize the separator** between the arguments you pass to `print()`. By default, the separator is a **space character**, which means that the values are separated by spaces. However, you can modify it to any character, integer, or string of your choice.
#
# Here are some examples to illustrate how the `sep` parameter works:
#
# 1. Using a **comma** as the separator. Notice `Sep=` value contains no space between the single quotes:
#    ```python
#    print('G', 'F', 'G', sep='')
#    # Output: GFG
#    ```
#
# 2. Using a **hyphen** as the separator:
#    ```python
#    print('09', '12', '2016', sep='-')
#    # Output: 09-12-2016
#    ```
#
# 3. Using an **at symbol (@)** as the separator:
#    ```python
#    print('pratik', 'geeksforgeeks', sep='@')
#    # Output: pratik@geeksforgeeks
#    ```
#
# The `sep` parameter can also be combined with the `end` parameter for even more flexibility. For instance:
#
# ```python
# print('G', 'F', sep='', end='')
# print('G')
# # Output: GFG
#
# print('09', '12', '2016', sep='-', end='\n')
# print('prtk', 'agarwal', sep='', end='@')
# print('geeksforgeeks')
# # Output:
# # 09-12-2016
# # prtkagarwal@geeksforgeeks
# ```
#
# Remember to specify the language as **Python 3** in your interactive Python IDE to try out these examples! 🐍✨
#
#
# Look at the code in the editor, and run it.
#
# The `sep` argument delivers the following results:
#
# **Output**
# ```
# My-name-is-Monty-Python.
# ```
#
# The `print()` function now uses a dash, instead of a space, to separate the outputted arguments.
#
# Note: the `sep` argument's value may be an empty string, too. Try it for yourself.

# %%
print('G', 'F', 'G', sep=' ')
# Output: GFG
# Out:
# G F G

# %%
print('G', 'F', 'G', sep='-')
# Output: G-F-G
# Out:
# G!F!G

# %%
print("My", "name", "is", "Monty", "Python.", sep="-")
# Out:
# My-name-is-Monty-Python.

# %%
print("My", "name", "is", "Monty", "Python.", sep="\n")
# Out:
# My
# name
# is
# Monty
# Python.

# %%
print("My", "name", "is", "Monty", "Python.", sep="\r")
# Out:
# Python.

# %%
print("Zahida", "Lee", sep="\r")
# Out:
# Lee

# %% [markdown]
# ## The `print()` function - the keyword arguments
# Both keyword arguments may be **mixed in one invocation**, just like here in the editor window.
#
# The example doesn't make much sense, but it visibly presents the interactions between `end` and `sep`.
#
# Can you predict the output?
#
# Run the code and see if it matches your predictions.
#
# Now that you understand the `print()` function, you're ready to consider how to store and process data in Python.
#
# Without `print()`, you wouldn't be able to see any results.

# %%
print("My", "name", "is", sep="_", end="***")
print("Monty", "Python.", sep="*", end="*\n")
print("OK")
# Out:
# My_name_is***Monty*Python.*
# OK

# %% [markdown]
# ## Some More exercises for you to Practice

# %%
print("My name is Yusuf.", end="*")
print("I love Python.", end="-")


print("I am learning in JustIT.")
# Out:
# My name is Yusuf.*I love Python.-I am learning in JustIT.

# %%
print("My name is Yusuf.", "I love Python.", end=" ")
print("I am learning in JustIT.")
# Out:
# My name is Yusuf. I love Python. I am learning in JustIT.

# %%
print("My name is Yusuf.", "I love Python.", end=3*"\n")
# Out:
# My name is Yusuf. I love Python.

# %%
print("My", "name", "is", "Monty", "Python.", sep="-")
# Out:
# My-name-is-Monty-Python.

# %%
print("My", "name", "is", "Monty", "Python.", sep="\n")
# Out:
# My
# name
# is
# Monty
# Python.

# %%
print("My", "name", "is", "Monty", "Python.", sep="\t")
# Out:
# My	name	is	Monty	Python.

# %% [markdown]
# Keyword argument must come after last positional argument.

# %%
print("My", "name", sep="\t", "is", "Monty", "Python.")
# Out:
#   File "<ipython-input-52-d2e7a6200b8f>", line 1
#     print("My", "name", sep="\t", "is", "Monty", "Python.")
#                                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
print("My", "name", "is",      "Monty",      "Python.", sep="*")

# %%
print("My", "name", "is", sep="_", end="*")
print("Monty", "Python.", sep="*", end="*\n")

# %%
print("My", "name", "is", sep="*", end="_")
print("Monty", "Python.", sep="\n", end="*")

# %% [markdown]
# ## Exercise/Lab!
#
# **Estimated time**
# 5-10 minutes
#
# **Level of difficulty**
# Very Easy
#
# **Objectives**
# becoming familiar with the `print()` function and its formatting capabilities;
# experimenting with Python code.
#
# **Scenario**
# Modify the first line of code in the editor, using the sep and end keywords, to match the expected output. Use the two `print()` functions in the editor.
#
# Don't change anything in the second `print()` invocation.
#
# **Code Provided below:**
#
# ```python
# print("Programming","Essentials","in")
# print("Python")
# ```
#
# **Expected output**
#
# `Programming***Essentials***in...Python`

# %%
#change the following two lines into Programming***Essentials***in...Python

print("Programming","Essentials","in")
print("Python")
# Out:
# Programming Essentials in
# Python

# %%
print("Programming***","Essentials***","in...")
print("\n")
print("Python")
# Out:
# Programming*** Essentials*** in...
#
#
# Python

# %%
print("Programming","Essentials","in", sep="***", end="...\n\n\nPython")
# Out:
# Programming***Essentials***in...
#
#
# Python

# %%
print("Programming***","Essentials", end="***")

print("in...\n")

print("Python", end="\n")
# Out:
# Programming*** Essentials***in...
#
# Python

# %% [markdown]
# ### Solution

# %%
print("Programming","Essentials","in", sep="***", end="...")
print("Python")
# Out:
# Programming***Essentials***in...Python

# %%
print("Programming","Essentials","in", sep="***",end="...")
print("Python")
# Out:
# Programming***Essentials***in...Python

# %%
name = "Sabrina"
name2 = "Sam"
age = 23
age2 = 45
city = "London"

print(name, ":Hey, how old are you?" )
print(name2, ":Hi, I'm", age ,"years old and you?")
print(name, ":I am", age2 ,"years old and I live in", city)
print(name2, ":I live in" ,city,"too")
# Out:
# Sabrina :Hey, how old are you?
# Sam :Hi, I'm 23 years old and you?
# Sabrina :I am 45 years old and I live in London
# Sam :I live in London too

# %% [markdown]
# # Python as a calculator - Operators
# Now, we're going to show you a completely new side of the print() function. You already know that the function is able to show you the values of the literals passed to it by arguments.
#
# In fact, it can do something more. Take a look at the snippet:
#
# `print(2+2)`
#
#
# Retype the code in the editor and run it. Can you guess the output?

# %%
print(3+5)
# Out:
# 8

# %%
3+5
# Out:
# 8

# %%
12 + 50
# Out:
# 62

# %%
1.5 + 2.3
# Out:
# 3.8

# %%
1.3 * 10
# Out:
# 13.0

# %% [markdown]
# How about adding without the `print()`

# %% [markdown]
# ###Python follows BODMAS or PEMDAS rules

# %%
(2+2)*9
# Out:
# 36

# %%
2+2*9
# Out:
# 20

# %%
2+3*(5*10/2)
# Out:
# 77.0

# %% [markdown]
# You should see the number four. Feel free to experiment with other operators.
#
# Without taking this too seriously, you've just discovered that Python can be used as a calculator. Not a very handy one, and definitely not a pocket one, but a calculator nonetheless.
#
# Taking it more seriously, we are now entering the province of operators and expressions.

# %% [markdown]
# ## Basic operators
# An **operator** is a symbol of the programming language, which is able to operate on the values.
#
# For example, just as in arithmetic, the` +` (plus) sign is the operator which is able to **add** two numbers, giving the result of the addition.
#
# Not all Python operators are as obvious as the plus sign, though, so let's go through some of the operators available in Python, and we'll explain which rules govern their use, and how to interpret the operations they perform.
#
# We'll begin with the operators which are associated with the most widely recognizable arithmetic operations:
#
# `+, -, *, /, //, %, **`
#
#
# The order of their appearance is not accidental. We'll talk more about it once we've gone through them all.
#
# **Remember:** Data and operators when connected together form **expressions.** The simplest expression is a literal itself.
#
# **A literal is data whose values are determined by the literal itself.** Such as `123` literally means what it's value denotes such as one hundred and 123 where as something line `'c'` can mean anything such as speed of light, some constant, centigrade?

# %% [markdown]
# ## Python Arithmetic Operators

# %%
print(2+3)
# Out:
# 5

# %%
print(2-3)
# Out:
# -1

# %%
2-3
# Out:
# -1

# %%
9*3
# Out:
# 27

# %% [markdown]
# ## Arithmetic operators: exponentiation
# A `**` (double asterisk) sign is an **exponentiation** (power) operator. Its left argument is the **base**, its right, the **exponent**.
#
# Classical mathematics prefers notation with superscripts, just like this: $2^{3}$. Pure text editors don't accept that, so Python uses` **` instead, e.g.,
#
# `2 ** 3`.
#
# Take a look at our examples in the editor window.
#
#
# Note: we've surrounded the double asterisks with spaces in our examples. It's not compulsory, but it improves the **readability** of the code.
#
# The examples show a very important feature of virtually all Python **numerical operators.**
#
# Run the code and look carefully at the results it produces. Can you see any regularity here?
#
#
# **Remember:** It's possible to formulate the following rules based on this result:
#
# 1. when **both** `**` arguments are integers, the result is an integer, too;
# 2. when **at least one** `**` argument is a float, the result is a float, too.
#
# This is an important distinction to remember.

# %%
print(2 ** 3)
print(2 ** 3.0)
print(2. ** 3)
print(2. ** 3.)
# Out:
# 8
# 8.0
# 8.0
# 8.0

# %%
2 ** 7
# Out:
# 128

# %% [markdown]
# Write Python code to calculate square root of 100. dont use any function

# %%
print("Square root of 100 is", 100 ** 0.5)
# Out:
# Square root of 100 is 10.0

# %%
print("Square root of 100 is", 100 **(1/2))
# Out:
# Square root of 100 is 10.0

# %% [markdown]
# ## Arithmetic operators: multiplication
#
# An `*` (asterisk) sign is a **multiplication** operator.
#
# Run the code below and check if our integer vs. float rule is still working.

# %%
print(2 * 3)
print(2 * 3.)
print(2. * 3)
print(2. * 3.)
# Out:
# 6
# 6.0
# 6.0
# 6.0

# %% [markdown]
# # Arithmetic operators: **division**
# A `/ `(slash) sign is a `divisional` operator.
#
# The value in front of the slash is a `dividend`, the value behind the slash, a **divisor**.
#
# Run the code below and analyze the results.

# %%
print(6 / 3)
print(6 / 3.)
print(6. / 3)
print(6. / 3.)
# Out:
# 2.0
# 2.0
# 2.0
# 2.0

# %% [markdown]
# You should see that there is an exception to the rule.
#
# **The result produced by the division operator is always a float,** regardless of whether or not the result seems to be a float at first glance: `1 / 2`, or if it looks like a pure integer: `2 / 1`.
#
# Is this a problem? Yes, it is. It happens sometimes that you really need a division that provides an integer value, not a float.
#
# Fortunately, Python can help you with that.

# %% [markdown]
# ## Arithmetic operators: **integer division**
#
# A `//` (double slash) sign is an integer divisional operator. It differs from the standard `/` operator in two details:
#
# * its result lacks the fractional part - it's absent (for integers), or is always equal to zero (for floats); this means that the **results are always rounded;**
# * it conforms to the integer vs. float rule.
#
# Run the example below and see the results:

# %%
print(6 // 3)
print(7 // 3.0)
print(6. // 3)
print(6. // 3.)
# Out:
# 2
# 2.0
# 2.0
# 2.0

# %%
print(14 / 3)
print(14 // 3)
# Out:
# 4.666666666666667
# 4

# %%
print(12 / 5)
print(12 // 5)
# Out:
# 2.4
# 2

# %%
x = 14 % 4
print( x * 3)
# Out:
# 6

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %% [markdown]
# As you can see, *integer by integer division* gives an integer result. All other cases produce floats.
#
#
# Let's do some more advanced tests.
#
# Look at the following snippet:

# %%
print(6 / 4)
print(6. / 4)
# Out:
# 1.5
# 1.5

# %% [markdown]
# <p>Imagine that we used <code>/</code> instead of <code>//</code> - could you predict the results?</p>
#
# <p>Yes, it would be <code>1.5</code> in both cases. That's clear.</p>
#
# <p>But what results should we expect with <code>//</code> division?</p>
#
# <p>Run the code and see for yourself.</p>
#
# <br>

# %%
print(6 // 4)
print(6. // 4)
# Out:
# 1
# 1.0

# %% [markdown]
# <p>What we get is two ones - one integer and one float.</p>
#
# <p>The result of integer division is always rounded to the nearest integer value that is less than the real (not rounded) result.</p>
#
# <p>This is very important: <strong>rounding always goes to the lesser integer</strong>.</p>
#
#
# <br>
#
# <p>Look at the code below and try to predict the results once again:</p>
# <code class="codep syntax-color"><div class="ace-tm"><div class="ace_static_highlight" style="counter-reset:ace_line 0"><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_keyword ace_operator">-</span><span class="ace_constant ace_numeric">6</span> <span class="ace_keyword ace_operator">//</span> <span class="ace_constant ace_numeric">4</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_constant ace_numeric">6.</span> <span class="ace_keyword ace_operator">//</span> <span class="ace_keyword ace_operator">-</span><span class="ace_constant ace_numeric">4</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line">
# </div></div></div></code>

# %%
print(6//4)
print(-6 // 4)
print(6. // -4)
# Out:
# 1
# -2
# -2.0

# %% [markdown]
# <br>
#
# <p>Note: some of the values are negative. This will obviously affect the result. But how?</p>
#
# <p>The result is two negative twos. The real (not rounded) result is <code>-1.5</code> in both cases. However, the results are the subjects of rounding. The <strong>rounding goes toward the lesser integer value</strong>, and the lesser integer value is <code>-2</code>, hence: <code>-2</code> and <code>-2.0</code>.</p>
#
#
# <p><span class="label" style="background-color:orange;"><b>NOTE</b></span></p>
# <p>Integer division can also be called <strong>floor division</strong>. You will definitely come across this term in the future.</p>
#
# <br>

# %%
8/3
# Out:
# 2.6666666666666665

# %%
8//3
# Out:
# 2

# %% [markdown]
# <div class="lab font-size-14">
#                     <!--
# Update history:
# 2020-07-17 Grzegorz (reformatted; code - syntax-color and blank lines added;)
# -->
#
# <h1>Operators: remainder (modulo)</h1>
#
#
# <p>The next operator is quite a peculiar one, because it has no equivalent among traditional arithmetic operators.</p>
#
# <p>Its graphical representation in Python is the <code>%</code> (percent) sign, which may look a bit confusing.</p>
#
# <p>Try to think of it as of a slash (division operator) accompanied by two funny little circles.</p>
#
# <p>The result of the operator is a <strong>remainder left after the integer division</strong>.</p>
#
# <p>In other words, it's the value left over after dividing one value by another to produce an integer quotient.</p>
#
# <p>Note: the operator is sometimes called <strong>modulo</strong> in other programming languages.</p>
#
# <p>Take a look at the snippet - try to predict its result and then run it:</p>
#
# <code class="codep syntax-color"><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_constant ace_numeric">14</span> <span class="ace_keyword ace_operator">%</span> <span class="ace_constant ace_numeric">4</span><span class="ace_paren ace_rparen">)</span>
# </code>
#
# <br>

# %%
print(14 % 4)
# Out:
# 2

# %% [markdown]
# <p>As you can see, the result is two. This is why:</p>
#
# <ul>
# <li><code>14 // 4</code>  gives <code>3</code> → this is the integer <strong>quotient</strong>;</li>
# <li><code>3 * 4</code>  gives <code>12</code> → as a result of <strong>quotient and divisor multiplication</strong>;</li>
# <li><code>14 - 12</code>  gives <code>2</code> → this is the <strong>remainder</strong>.</li>
# </ul>
#
# <br>
#
# <p>This example is somewhat more complicated:</p>
#
# <code class="codep syntax-color"><div class="ace-tm"><div class="ace_static_highlight" style="counter-reset:ace_line 0"><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_constant ace_numeric">12</span> <span class="ace_keyword ace_operator">%</span> <span class="ace_constant ace_numeric">4.5</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line">
# </div></div></div></code>
#
# <br>
#
# <p>What is the result?</p>
#
# <button class="button tiny" onclick="solution('sol')">Check</button>

# %%
print(12 % 4.5)
# Out:
# 3.0

# %%
# how to use modulo to restrict upto 2 decimal places

pi = 3.141592653589793238462643383279502884197
formatted_pi = "%.2f" % pi
print(formatted_pi)
# Out:
# 3.14

# %%
# how to use .format to restrict upto 2 decimal places

pi = 3.141592653589793238462643383279502884197
formatted_pi = "{:.2f}".format(pi)
print(formatted_pi)
# Out:
# 3.14

# %% [markdown]
# <br>
#
# <p id="sol" style="display: none;"><code style="color:green;">3.0</code> - not <code>3</code> but <code>3.0</code> (the rule still works: <code>12 // 4.5</code> gives <code>2.0</code>; <code>2.0 * 4.5</code> gives <code>9.0</code>; <code>12 - 9.0</code> gives <code>3.0</code>)</p>
#
#
# <script>
# function solution (id) {
#     var element = document.getElementById(id);
#
# if (element.style.display === "none") {
#         element.style.display = "block";
#     } else {
#         element.style.display = "none";
#     }
# }
# </script>
#
#
# <br>
# <h1>Operators: how not to divide</h1>
#
#
# <p>As you probably know, <strong>division by zero doesn't work</strong>.</p>
#
# <p>Do <b>not</b> try to:</p>
#
# <ul>
# <li>perform a division by zero;</li>
# <li>perform an integer division by zero;</li>
# <li>find a remainder of a division by zero.</li>
# </ul>
#
# <br>

# %% [markdown]
# ### Over to you: Try to predict the outcome of teh following before you run the following snippets.

# %%
print(12/3)

# %%
print(12%3)

# %%
print(7%3)
# Out:
# 1

# %%
print(12%5)

# %%
print(2**3)

# %%
print(3**2)

# %%
print(10*90/100)

# %%
print(12/3)

# %%
print(12//3)

# %% [markdown]
# How to round output into 2 decimal places?

# %%
print(14/3)

# %%
print(14//3)

# %%
print(258//12)

# %%
print(258/12)

# %% [markdown]
# <div class="small-12 large-6 columns">
#
# <h1>List of priorities</h1>
#
#
# <p>Since you're new to Python operators, we don't want to present the complete list of operator priorities right now.</p>
#
# <p>Instead, we'll show you a truncated form, and we'll expand it consistently as we introduce new operators.</p>
#
# <p>Look at the table below:</p>
#
# <table style="width:75%">
#
# <tbody><tr>
# <th>Priority</th>
# <th>Operator</th>
# <th></th>
# </tr>
#
# <tr>
# <td>1</td>
# <td><code>**</code></td>
# <td></td>
# </tr>
#
# <tr>
# <td>2</td>
# <td><code>+</code>, <code>-</code> (note: unary operators located next to the right of the power operator bind more strongly)</td>
# <td>unary</td>
# </tr>
#
# <tr>
# <td>3</td>
# <td><code>*</code>, <code>/</code>, <code>//</code>, <code>%</code></td>
# <td></td>
# </tr>
#
# <tr>
# <td>4</td>
# <td><code>+</code>, <code>-</code></td>
# <td>binary</td>
# </tr>
#
# </tbody></table>
#
# <br>
#
# <p>Note: we've enumerated the operators in order <strong>from the highest (1) to the lowest (4) priorities</strong>.</p>
#
# <br>
#
# <p>Try to work through the following expression:</p>
#
# <code class="codep syntax-color"><div class="ace-tm"><div class="ace_static_highlight" style="counter-reset:ace_line 0"><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_constant ace_numeric">2</span> <span class="ace_keyword ace_operator">*</span> <span class="ace_constant ace_numeric">3</span> <span class="ace_keyword ace_operator">%</span> <span class="ace_constant ace_numeric">5</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line">
# </div></div></div></code>
#
# <br>
#
# <p>Both operators (<code>*</code> and <code>%</code>) have the same priority, so the result can be guessed only when you know the binding direction. What do you think? What is the result?</p>
#
# <button class="button tiny" onclick="solution('sol')">Check</button>
#
# <br>
#
# <p id="sol" style="display: block;">
# <code>1</code>
# </p>
#
#
# <script>
# function solution (id) {
#     var element = document.getElementById(id);
#
# if (element.style.display === "none") {
#         element.style.display = "block";
#     } else {
#         element.style.display = "none";
#     }
# }
# </script>
#
#
# <br>
#
# </div>

# %% [markdown]
# <div class="small-12 large-6 columns">
#
#
# <h1>Operators and parentheses</h1>
#
#
# <p>Of course, you're always allowed to use <strong>parentheses</strong>, which can change the natural order of a calculation.</p>
#
# <p>In accordance with the arithmetic rules, <strong>subexpressions in parentheses are always calculated first</strong>.</p>
#
# <p>You can use as many parentheses as you need, and they're often used to <strong>improve the readability</strong> of an expression, even if they don't change the order of the operations.</p>
#
# <p>An example of an expression with multiple parentheses is here:</p>
#
#
# <code class="codep syntax-color"><div class="ace-tm"><div class="ace_static_highlight" style="counter-reset:ace_line 0"><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">((</span><span class="ace_constant ace_numeric">5</span> <span class="ace_keyword ace_operator">*</span> <span class="ace_paren ace_lparen">((</span><span class="ace_constant ace_numeric">25</span> <span class="ace_keyword ace_operator">%</span> <span class="ace_constant ace_numeric">13</span><span class="ace_paren ace_rparen">)</span> <span class="ace_keyword ace_operator">+</span> <span class="ace_constant ace_numeric">100</span><span class="ace_paren ace_rparen">)</span> <span class="ace_keyword ace_operator">/</span> <span class="ace_paren ace_lparen">(</span><span class="ace_constant ace_numeric">2</span> <span class="ace_keyword ace_operator">*</span> <span class="ace_constant ace_numeric">13</span><span class="ace_paren ace_rparen">))</span> <span class="ace_keyword ace_operator">//</span> <span class="ace_constant ace_numeric">2</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line">
# </div></div></div></code>
#
#
# <br>
#
# <p>Try to compute the value that's printed to the console. What's the result of the <code>print()</code> function?</p>
#
# <button class="button tiny" onclick="solution('sol2')">Check</button>
#
#
# <p id="sol2" style="display: none;"><code>10.0</code></p>
#
# <script>
# function solution (id) {
#     var element = document.getElementById(id);
#
# if (element.style.display === "none") {
#         element.style.display = "block";
#     } else {
#         element.style.display = "none";
#     }
# }
# </script>
#
#
#
# <br>
#
#
#
# </div>

# %% [markdown]
# ###Extension: You can try other Arithmatic operators from the following links
#
# | Operator | Name           | Example  | Try it                                                                                 |
# | -------- | -------------- | -------- | -------------------------------------------------------------------------------------- |
# | +        | Addition       | x + y    | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_oper_add)      |
# | \-       | Subtraction    | x - y    | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_oper_sub)      |
# | \*       | Multiplication | x \* y   | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_oper_mult)     |
# | /        | Division       | x / y    | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_oper_div)      |
# | %        | Modulus        | x % y    | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_oper_mod)      |
# | \*\*     | Exponentiation | x \*\* y | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_oper_exp)      |
# | //       | Floor division | x // y   | [Try it »](https://www.w3schools.com/python/trypython.asp?filename=demo_oper_floordiv) |

# %% [markdown]
# # Commenting in Python

# %% [markdown]
# Ctrl + / makes line a comment

# %%
# It calculates sum
# 3*2

"""
This is a multiline comment.
It can span multiple lines.
"""

# """
# This is a multiline comment.
# It can span multiple lines.
# """
# Out:
# '\nThis is a multiline comment.\nIt can span multiple lines.\n'

# %%
"""
This is a multiline comment.
It can span multiple lines.
"""
9*3
# Out:
# 27

# %% [markdown]
# Using `ctrl + /` for multiline commenting
#
# * first select the lines of code that you want to comment out
# * then press `ctrl+/` to comment the selected lines.

# %%
# """
# This is a multiline comment.
# It can span multiple lines.
# """
# 9*3

# %%
#Get back to this later

# %%
# add question

# %%
2+3
# Out:
# 5

# %%
# we are multiplying below
9*3
# Out:
# 27

# %% [markdown]
# #Python Variables
# ----

# %% [markdown]
# <div class="row">
#
# <div class="small-12 large-6 columns">
#
# <h1>What are variables?</h1>
#
#
#
# <p>It seems fairly obvious that Python should allow you to encode literals carrying number and text values.</p>
#
# <p>You already know that you can do some arithmetic operations with these numbers: add, subtract, etc. You'll be doing that many times.</p>
#
# <p>But it's quite a normal question to ask how to <strong>store the results</strong> of these operations, in order to use them in other operations, and so on.</p>
#
# <p>How do you save the intermediate results, and use them again to produce subsequent ones?</p>
#
# <p>Python will help you with that. It offers special "boxes" (containers) for that purpose, and these boxes are called <strong>variables</strong> - the name itself suggests that the content of these containers can be varied in (almost) any way.</p>
#
# <p>What does every Python variable have?</p>
#
# <ul>
# <li>a name;</li>
# <li>a value (the content of the container)</li>
# </ul>
#
# <p>Let's start with the issues related to a variable's name.</p>
#
# <p>Variables do not appear in a program automatically. As developer, you must decide how many and which variables to use in your programs.</p>
#
# <p>You must also name them.</p>
#
# <br>
#
# </div>
#
#
#
#
# <div class="small-12 large-6 columns">
#
#
#
#
# <p>If you want to <strong>give a name to a variable</strong>, you must follow some strict rules:</p>
#
# <ul>
#
# <li>the name of the variable must be composed of upper-case or lower-case letters, digits, and the character <code>_</code> (underscore)</li>
# <li>the name of the variable must begin with a letter;</li>
# <li>the underscore character is a letter;</li>
# <li>upper- and lower-case letters are treated as different (a little differently than in the real world - <i>Alice</i> and <i>ALICE</i> are the same first names, but in Python they are two different variable names, and consequently, two different variables);</li>
# <li>the name of the variable must not be any of Python's [reserved word] (https://flexiple.com/python/python-reserved-words) the keywords - we'll explain more about this soon.</li>
#
# </ul>
#
#
#
# <center><img src="/content/drive/MyDrive/WK09-Python/Variable container.png" width="45%" alt="The concept of variables as a box"></center>

# %% [markdown]
# <div class="small-12 large-6 columns">
#
# <h1>Using variables</h1>
#
# <p>You're allowed to use as many variable declarations as you need to achieve your goal, like this:</p>
#
# <code class="codep syntax-color"><div class="ace-tm"><div class="ace_static_highlight" style="counter-reset:ace_line 0"><div class="ace_line"><span class="ace_identifier">var</span> <span class="ace_keyword ace_operator">=</span> <span class="ace_constant ace_numeric">1</span>
# </div><div class="ace_line"><span class="ace_identifier">account_balance</span> <span class="ace_keyword ace_operator">=</span> <span class="ace_constant ace_numeric">1000.0</span>
# </div><div class="ace_line"><span class="ace_identifier">client_name</span> <span class="ace_keyword ace_operator">=</span> <span class="ace_string">'John Doe'</span>
# </div><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_identifier">var</span><span class="ace_punctuation">,</span> <span class="ace_identifier">account_balance</span><span class="ace_punctuation">,</span> <span class="ace_identifier">client_name</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_identifier">var</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line">
# </div></div></div></code>
#
# <br>
#
# <p>You're <b>not allowed to use a variable which doesn't exist</b> (in other words, a variable that was not assigned a value).</p>
#
# <p>This example will <strong>cause an error</strong>:</p>
#
# <mark style="background-color:#e6f2ff;">v</mark>ar = 1
#
# print(<mark style="background-color:#e6f2ff;">V</mark>ar)
#
#
#
#
# <br>
#
# <p>We've tried to use a variable named <code>Var</code>, which doesn't have any value (note: <code>var</code> and <code>Var</code> are different entities, and have nothing in common as far as Python's concerned).</p>
#
# <br>
#
# </div>

# %%
name = "Yusuf"
name
# Out:
# 'Yusuf'

# %%
name
# Out:
# 'Yusuf'

# %%
#the folowing will throw in an error when you run it
9var = 1
# Out:
#   File "<ipython-input-193-9992e24bca65>", line 2
#     9var = 1
#     ^
# SyntaxError: invalid decimal literal

# %%
var = 1
account_balance = 1000.0
client_name = 'John Doe'
print(var, account_balance, client_name)
print(var)
print(account_balance)
# Out:
# 1 1000.0 John Doe
# 1
# 1000.0

# %%
print(var)
# Out:
# 1

# %%
var
# Out:
# 1

# %%
# you can overwrite the previous variable (var in this case) if you assign it a new value
var = 1500

# %%
print(var)
# Out:
# 1500

# %%
var

# %%
var == 1
# Out:
# False

# %%
var == 1500
# Out:
# True

# %%
var = 1
print(var)
# Out:
# 1

# %% [markdown]
# <div class="small-12 large-6 columns">
#
# <h1></h1>
#
#
# <p><span class="label" style="background-color:orange"><b>REMEMBER</b></span></p>
#
# <p>You can use the <code>print()</code> function and combine text and variables using the <code>+</code> operator to output strings and variables, e.g.:</p>
#
# ```
# var = "3.8.5"
# print("Python version: " + var)
# ```
#
# <br>
#
# <p>Can you guess the output of the snippet above?</p>
#
# <button class="button tiny" onclick="solution('sol')">Check</button>
#
# <p id="sol" style="display: block;">
# <code class="codep ">Python version: 3.8.5</code>
# </p>
#
# <script>
# function solution (id) {
#     var element = document.getElementById(id);
#
# if (element.style.display === "none") {
#         element.style.display = "block";
#     } else {
#         element.style.display = "none";
#     }
# }
# </script>
#
# <br>
#
# </div>

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
version = "3.10.12"
print("Python version: " + version)
# Out:
# Python version: 3.10.12

# %% [markdown]
# ## Variables Exercises

# %%
name = "Yusuf"
age = 18
location = "UK"

# %%
print(name)
# Out:
# Yusuf

# %%
print("name")
# Out:
# name

# %%
print(age)
# Out:
# 18

# %%
location
# Out:
# 'UK'

# %%
print(location)
# Out:
# UK

# %%
pi = 3.14

# %%
print(pi)

# %%
amiright = True

# %%
print(amiright)
# Out:
# True

# %% [markdown]
# ### Exercise 1
#
# 1. name a variable called 'my age'. what happens if you put a space between `my age`. Try overcoming thsi problem by using` _ `character inbetween.
# 2. store in this variable a value of your actual age in integers. This is called assignment.
# 3. print this variable using print()

# %%
my_age = 40
print(my_age)
# Out:
# 40

# %% [markdown]
# #### Exercise 2

# %%
my_age = 33

your_age = 30

my_age = your_age

print(my_age)
# Out:
# 30

# %% [markdown]
# Variable name can not contain a space

# %%
# the following will throw an error guess why?
favorite movie = "3 Idiots" #Amir Khan movie

# %%
#underscoring between two words might be a solution.
favorite_movie = "3 Idiots" #Amir Khan movie

# %%
print(favorite_movie)

# %% [markdown]
# #### Exercise

# %% [markdown]
# Design an algorithm to add two numbers and display the result.

# %%
num1 = 14
print("my first number is ", num1)
num2 = 15
print("my second number is ", num2)
summation = num1+num2
print("Addition of", num1, "and", num2, "is equal to", summation, end=".")
# Out:
# my first number is  14
# my second number is  15
# Addition of 14 and 15 is equal to 29.

# %% [markdown]
# ### Can you declare/assign variables anywhere in Python?

# %%
num1 = 14
num2 = 15
summation = num1+num2
print("my first number is ", num1)
print("my second number is ", num2)
print("Addition of", num1, "and", num2, "is equal to", summation, end=".")
# Out:
# my first number is  14
# my second number is  15
# Addition of 14 and 15 is equal to 29.

# %%
# Corrected Python code for Sabrina
# Question: Can you use £ next to a variable?

# Correct the variable names to follow Python naming conventions
firstname = "Stan"
lastname = "Smith"

# Remove commas from the BankBalance for it to be treated as an integer
bank_balance = 1000000
amount_withdrawn = 1000

# Correct the calculation of NewBalance
new_balance = bank_balance - amount_withdrawn

# Correct the print statement to include commas and proper string concatenation
print("Customer Detail: " + firstname + " " + lastname + " £" + str(new_balance))
# Out:
# Customer Detail: Stan Smith £999000

# %%
# Corrected Python code with formatted balance
# Question: Can you use £ next to a variable for shwoing thousand such that there is a , separator between the values?

# Correct the variable names to follow Python naming conventions
firstname = "Stan"
lastname = "Smith"

# Remove commas from the BankBalance for it to be treated as an integer
bank_balance = 1000000
amount_withdrawn = 1000

# Correct the calculation of NewBalance
new_balance = bank_balance - amount_withdrawn

# Format the new_balance with commas as thousands separators
formatted_new_balance = f"{new_balance:,}"

# Correct the print statement to include commas and proper string concatenation
print(f"Customer Detail: {firstname} {lastname} £{formatted_new_balance}")

# When you run this corrected code, it will display the following output:
# Customer Detail: Stan Smith £999,000
# Out:
# Customer Detail: Stan Smith £999,000

# %%
# do not assign varabile to a function like in this exmaple (print = 21)

# %%
#you can not assign a variable to keywords
if = 10
# Out:
#   File "<ipython-input-13-6b54332f1cb7>", line 2
#     if = 10
#        ^
# SyntaxError: invalid syntax

# %%
My_name = "Yusuf"

# %%
My_name
# Out:
# 'Yusuf'

# %%
True = 12
# Out:
#   File "<ipython-input-11-abb8adb6eb95>", line 1
#     True = 12
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# #### Exercise

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myName = "Hubert Blaine Wolfeschlegelsteinhausenbergerdorff Sr"

# %%
print(myName)

# %%
print(type(myName))
# Out:
# <class 'str'>

# %%
print(len(myName))
# Out:
# 52

# %% [markdown]
# # Challenge Lab & Exercise
#
# <h2>Estimated time</h2>
# <p>15 minutes</p>
#
# <h2>Level of difficulty</h2>
# <p>Medium</p>
#
# <h2>Objectives</h2>
# <ul>
# <li>becoming familiar with the concept of storing and working with different data types in Python;</li>
# <li>experimenting with Python code.</li>
# </ul>
#
# <h2>Scenario</h2>
# <p>Here is a short story:</p>
# <p>Once upon a time in Appleland, John had three apples, Mary had five apples, and Adam had six apples. They were all very happy and lived for a long time. End of story.</p>
# <h2>Your task is to:<h2>
# <ul>
# <li>create the variables: <code>john</code>, <code>mary</code>, and <code>adam</code>;</li>
# <li>assign values to the variables. The values must be equal to the numbers of fruit possessed by John, Mary, and Adam respectively;</li>
# <li>having stored the numbers in the variables, print the variables on one line, and separate each of them with a comma;</li>
# <li>now create a new variable named <code>total_apples</code> equal to addition of the three former variables.</li>
# <li>print the value stored in <code>total_apples</code> to the console;</li>
# <li><strong>experiment with your code</strong>: create new variables, assign different values to them, and perform various arithmetic operations on them (e.g., +, -, *, /, //, etc.). Try to print a string and an integer together on one line, e.g., <code>"Total number of apples:"</code> and <code>total_apples</code>.</li>
# </ul>
#
# <br>
#                 </div>

# %% [markdown]
# ## Solution1

# %%
# create variables
john = 3
mary = 5
adam = 6

# print variables on one line
print("John has", john, "apples, Mary has", mary, "apples, and Adam has", adam, "apples.")

# create new variable
total_apples = john + mary + adam

# print total apples
print("Total number of apples:", total_apples)

# experiment with code
a = 10
b = 5
c = a - b
print("Value of a:", a, ", value of b:", b, ", value of c:", c)
# Out:
# John has 3 apples, Mary has 5 apples, and Adam has 6 apples.
# Total number of apples: 14
# Value of a: 10 , value of b: 5 , value of c: 5

# %% [markdown]
# This code creates three variables `john`,` mary`, and `adam` and assigns them values of 3, 5, and 6 respectively. It then prints the values of these variables on one line, separated by commas, using the `,` operator to separate the values. A new variable total_apples is created by adding the values of the three former variables. The value of total_apples is then printed to the console using the , operator. Finally, the code creates three new variables a, b, and c, assigns them values of 10, 5, and the difference between a and b respectively, and prints a string and an integer together on one line using the `,` operator.

# %% [markdown]
# ## Solution 2 - Using f-string literal (formatted string literals)
#
# In this example, the variables names are substituted into the string using curly braces `{}` inside the f-string. The values of the variables are then displayed in the output.
#
# you can also explore `.format()` as well.

# %%
# create variables
john = 3
mary = 5
adam = 6

#old method of printing on one line
#print("John has", john, "apples, Mary has", mary, "apples, and Adam has", adam, "apples.")
# print variables in one line using string literal
print(f"John has {john} apples, Mary has {mary} apples, and Adam has {adam} apples.")

# create new variable
total_apples = john + mary + adam

# print total apples
print(f"Total number of apples: {total_apples}")

# experiment with code
a = 10
b = 5
c = a - b
print(f"Value of a: {a}, value of b: {b}, value of c: {c}")

# %% [markdown]
# #<h1>The <span style="font-family:courier new;">input()</span> function</h1>
#
#
# <p>We're now going to introduce you to a completely new function, which seems to be a mirror reflection of the good old <code>print()</code> function.</p>
#
# <p>Why? Well, <code>print()</code> sends data to the console.</p>
#
# <p>The new function gets data from it.</p>
#
#
# <p><code>print()</code> has no usable result. The meaning of the new function is to <strong>return a very usable result</strong>.</p>
#
#
# <p>The function is named <code>input()</code>. The name of the function says everything.</p>
#
#
# <p>The <code>input()</code> function is able to read data entered by the user and to return the same data to the running program.</p>
#
# <p>The program can manipulate the data, making the code truly interactive.</p>
#
# <p>Virtually all programs <strong>read and process data</strong>. A program which doesn't get a user's input is a <strong>deaf program</strong>.</p>
#
# <p>Take a look at our example:</p>
#
# <code class="codep syntax-color"><div class="ace-tm"><div class="ace_static_highlight" style="counter-reset:ace_line 0"><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_string">"Tell me anything..."</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line"><span class="ace_identifier">anything</span> <span class="ace_keyword ace_operator">=</span> <span class="ace_support ace_function">input</span><span class="ace_paren ace_lparen">(</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line"><span class="ace_keyword">print</span><span class="ace_paren ace_lparen">(</span><span class="ace_string">"Hmm..."</span><span class="ace_punctuation">,</span> <span class="ace_identifier">anything</span><span class="ace_punctuation">,</span> <span class="ace_string">"... Really?"</span><span class="ace_paren ace_rparen">)</span>
# </div><div class="ace_line">
# </div></div></div></code>
#
# <br>
#
# <p>It shows a very simple case of using the <code>input()</code> function.</p>
#
# </div>
#
# <div class="small-12 large-6 columns">
#
# <h1></h1>
#
# <p>Note:</p>
#
# <ul>
# <li>The program <strong>prompts the user to input some data</strong> from the console (most likely using a keyboard, although it is also possible to input data using voice or image);</li>
#
# <li>the <code>input()</code> function is invoked without arguments (this is the simplest way of using the function); the function will <strong>switch the console to input mode</strong>; you'll see a blinking cursor, and you'll be able to input some keystrokes, finishing off by hitting the <i>Enter</i> key; all the inputted data will be <strong>sent to your program</strong> through the function's result;</li>
# <li>note: you need to assign the result to a variable; this is crucial - missing out this step will cause the entered data to be lost;</li>
# <li>then we use the <code>print()</code> function to output the data we get, with some additional remarks.</li>
# </ul>
#
# <p>Try to run the code and let the function show you what it can do for you.</p>
#
#
# <br>
#
# <center><img src="/uploads/media/default/0001/01/8a65a4a463dd843c841024c5a9eab156a6695453.png"></center>
#
# <br>
#
# </div>

# %%
print("Tell me anything...")
anything = input()
print("Hmm...", anything, "... Really?")
# Out:
# Tell me anything...
# Python
# Hmm... Python ... Really?

# %%
print(input())
# Out:
# 258
# 258

# %%
something = input("Tell me something...")
print("Hmm...", something, "...Really?")
# Out:
# Tell me something...123
# Hmm... 123 ...Really?

# %%
age = input("please enter your age...")
print("Hmm.. you are", age, "years old.")
# Out:
# please enter your age...123
# Hmm.. you are 123 years old.

# %%
age = input("please enter your age...")
# Out:
# please enter your age...258

# %%
age
# Out:
# '258'

# %%
name = input("What is your name...")
print("Hmm.. your name is", name)
# Out:
# What is your name...Mr.X
# Hmm.. your name is Mr.X

# %%
time_hour = input("tell me time in hrs. I will calculate in seconds.")
print("Time in seconds is:", time_hour*60*60)
# Out:
# tell me time in hrs. I will calculate in seconds.1
# Time in seconds is: ...

# %%
time_hour = input("tell me time in hrs. I will calculate in seconds.")
print(type(time_hour))
print("Time in seconds is:", time_hour*60*60)
# Out:
# tell me time in hrs. I will calculate in seconds.2
# <class 'str'>
# Time in seconds is: ...

# %% [markdown]
# ##Type Casting
# converting into `int()` and `float()`

# %%
myage = "32"
print(type(myage))
# convert mayage from string to integer
print(type(int(myage)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
myage = 32
print(type(myage))
# convert mayage from interger to string
print(type(str(myage)))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# help(str), help(int), help(float)

# %%
time_hour = float(input("tell me time in hours. I will calculate in seconds."))
print("Time in seconds is:", time_hour*60*60)
# Out:
# tell me time in hours. I will calculate in seconds.2
# Time in seconds is: 7200.0

# %%
#extension!!
# how do I ensure that the person always puts in a float?
# we shall cover whileloop later
while True:
    try:
        time_hour = float(input("Tell me time in hours. I will calculate in seconds: "))
        break  # Exit the loop if the input is a valid float
    except ValueError:
        print("Invalid input. Please enter a number.")

print("Time in seconds is:", time_hour * 60 * 60)
# Out:
# Tell me time in hours. I will calculate in seconds: ali baab
# Invalid input. Please enter a number.
# Tell me time in hours. I will calculate in seconds: 2
# Time in seconds is: 7200.0

# %% [markdown]
# ### Can you spot the error in the following Snippet?:
#
# Hint: `TypeCasting`

# %%
time_second = input("tell me time in seconds. I will calculate in hours.")
print("Hmm.. you are", time_second/60, "years old.")
# Out:
# tell me time in seconds. I will calculate in hours.2587
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-251-b021c5e4292f> in <cell line: 0>()
#       1 time_second = input("tell me time in seconds. I will calculate in hours.")
# ----> 2 print("Hmm.. you are", time_second/60, "years old.")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
# get time in seconds from user
time_second = int(input("Tell me time in seconds. I will calculate in hours: "))

# calculate time in hours
time_hour = time_second / 3600

# print result
print("Hmm.. you have been alive for approximately", time_hour, "hours.")
# Out:
# Tell me time in seconds. I will calculate in hours: 2587
# Hmm.. you have been alive for approximately 0.7186111111111111 hours.

# %%
anything = input("Enter a number: ")
something = anything ** 2
print(anything, "to the power of 2 is", something)
# Out:
# Enter a number: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-253-3cefdaad2f9e> in <cell line: 0>()
#       1 anything = input("Enter a number: ")
# ----> 2 something = anything ** 2
#       3 print(anything, "to the power of 2 is", something)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
#add int function before input that will change datatype before storing
anything = int(input("Enter a number: "))
something = anything ** 2.0
print(anything, "to the power of 2 is", something)
# Out:
# Enter a number: 2
# 2 to the power of 2 is 4.0

# %%
#add int function before input that will change datatype before storing
anything = int(input("Enter a number: "))
something = anything ** 2.0
print(anything, "to the power of 2 is", something)
# Out:
# Enter a number: 10
# 10 to the power of 2 is 100.0

# %%
#add float function before input that will change datatype before storing
anything = float(input("Enter a number: "))
something = anything ** 2.0
print(anything, "to the power of 2 is", something)
# Out:
# Enter a number: 2.5
# 2.5 to the power of 2 is 6.25

# %%
anything = int(input("Enter a number: "))



something = anything ** 2.0



print(anything, "to the power of 2 is", something)

# %% [markdown]
# #### Exercise − Design a calculator that will get two numbers from user, make arithmetic operations and display the result.

# %%
print("Simple Addition Calculator")



try:

    num1 = int(input("Enter the first number: "))

    num2 = int(input("Enter the second number: "))

    result = num1 + num2

    print("Result:", result)

except ValueError:

    print("Invalid input. Please enter valid integers.")
# Out:
# Simple Addition Calculator
# Enter the first number: 20.6
# Invalid input. Please enter valid integers.

# %%
anything = int(input ("Enter a number:"))

something = anything / 11

print(anything, "divided by 11 is", something)
# Out:
# Enter a number:20
# 20 divided by 11 is 1.8181818181818181

# %%
x = float(input("Enter number 1: "))

y = float(input("Enter number 2: "))

sum = float(x+y)



print("Sum of x and y = ", x+y)

print("Sum of x and y", sum)
# Out:
# Enter number 1: 20
# Enter number 2: 25
# Sum of x and y =  45.0
# Sum of x and y 45.0

# %% [markdown]
# ## Can you spot the problem with the following?

# %%
anything1 = int(input("Enter a number: "))
anything2 = int(input("Enter a number: "))



output = anything1 + anything2



print("Your inputs are", anything1, "and", anything2, "\nThe total of your two inputs is", output)
# Out:
# Enter a number: 30+25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-010ef739451e> in <cell line: 1>()
# ----> 1 anything1 = int(input("Enter a number: "))
#       2 anything2 = int(input("Enter a number: "))
#       3
#       4
#       5
#
# ValueError: invalid literal for int() with base 10: '30+25'

# %%
# get input from user and convert to integer
anything1 = int(input("Enter a number: "))
anything2 = int(input("Enter a number: "))

# calculate output
output = anything1 + anything2

# print result
print(f"Your inputs are {anything1}, and {anything2}\nThe total of your two inputs is {output}")
# Out:
# Enter a number: 10
# Enter a number: 20
# Your inputs are 10, and 20
# The total of your two inputs is 30

# %%
# This function adds two numbers
def add(x, y):
    return x + y

# This function subtracts two numbers
def subtract(x, y):
    return x - y

# This function multiplies two numbers
def multiply(x, y):
    return x * y

# This function divides two numbers
def divide(x, y):
    return x / y


print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    # take input from the user
    choice = input("Enter choice(1/2/3/4): ")

    # check if choice is one of the four options
    if choice in ('1', '2', '3', '4'):
        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input. Please enter a number.")
            continue

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))

        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))

        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))

        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))

        # check if user wants another calculation
        # break the while loop if answer is no
        next_calculation = input("Let's do next calculation? (yes/no): ")
        if next_calculation == "no":
          break
    else:
        print("Invalid Input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 2
# Enter first number: 25
# Enter second number: 21
# 25.0 - 21.0 = 4.0
# Let's do next calculation? (yes/no): no

# %%
number1= int(input("Enter the first number:"))

number2= int(input("Enter the second number:"))

sum=number1+number2;

print("Addition",sum)

sub=number1-number2;

print("subtraction:",sub)

multipication=number1*number2;

print("multiplication:",multipication)

division=number1/number2;

print("Division:",float(division))
# Out:
# Enter the first number:25
# Enter the second number:25
# Addition 50
# subtraction: 0
# multiplication: 625
# Division: 1.0

# %%
print("Ali", "Baba")
print("Forty" + "Thieves")

print("3", 4)

print(3+4)

print("3"+ 4 )
# Out:
# Ali Baba
# FortyThieves
# 3 4
# 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a67fd5d58883> in <cell line: 8>()
#       6 print(3+4)
#       7
# ----> 8 print("3"+ 4 )
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Day 1 Exercises

# %% [markdown]
# 1) Create a program that takes a user's name and age as input and prints a greeting message.

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print("Hello,", name, "You are", age, "years old.")
print(f"Hello, {name}! You are {age} years old.") #f string
# Out:
# Enter your name: yusuf
# Enter your age: 21
# Hello, yusuf You are 21 years old.
# Hello, yusuf! You are 21 years old.

# %% [markdown]
# 2) Write a Python program that allows a user to input the dimensions of a room (length and width) and then calculates how much carpet is needed to cover the floor, i.e., the area of the room. ![image.png](data:image/png;base64,...)

# %%
length=float(input('enter length:'))
width=float(input('enter width:'))
area=length*width
print('carpet required to cover the area' + ' '+ str(area))
print(f"carpet required to cover the area is {area}")
# Out:
# enter length:2.5
# enter width:3
# carpet required to cover the area 7.5
# carpet required to cover the area is 7.5

# %%
# print("hello"+2) # will fail beacuse you cant add string to number

# %% [markdown]
# 3) Create a program that will convert todays temperature from Celsius to Fahrenheit, Refer to image. ![image.png](data:image/png;base64,...)

# %%
# Taking temperature input in Celsius
celsius = float(input("Enter temperature in Celsius: "))
# Converting to Fahrenheit
fahrenheit = (celsius * 9/5) + 32
# Displaying the result
print(f"{celsius}°C is equal to {fahrenheit}°F.")
print(str(celsius) +"°C is equal to " + str(fahrenheit) + "°F.")
print(celsius, "\b°C is equal to", fahrenheit, "°F.")
# Out:
# Enter temperature in Celsius: 2.5
# 2.5°C is equal to 36.5°F.
# 2.5°C is equal to 36.5°F.
# °C is equal to 36.5 °F.

# %% [markdown]
# 4) Create a program that will convert distance from miles to km or km to miles. Refer to image.

# %%
miles= float(input("Miles:"))
kilometers= round(miles * 1.60934,2)
print(f"The distance in kilometers: {kilometers}")
# Out:
# Miles:3
# The distance in kilometers: 4.83

# %%
kms= float(input("kilometers:"))
miles= kms / 1.60934
print(f"The distance in miles: {miles}")
# Out:
# kilometers:20
# The distance in kilometers: 12.427454732996136

# %% [markdown]
# 5) Write a program that will give you the sum of 3 digits. See example.(Hint: use you can use floor division and modulus operator.) ![image.png](data:image/png;base64,...)

# %%
number = int(input("Enter a three-digit number: "))
hundreds = number // 100
print(hunderds)
tens = (number % 100) // 10
print(tens)
ones = number % 10
print(ones)
sum_of_digits= hundreds + tens + ones
print(f"The sum of the digits of {number} is {sum_of_digits}.")
# Out:
# Enter a three-digit number: 258
# 2
# 5
# 8
# The sum of the digits of 258 is 15.

# %% [markdown]
# 6) Write a program that will reverse a four digit number. See example below. (Hint: use floor division and modulus operator) ![image.png](data:image/png;base64,...)

# %%
number = int(input('Enter a number with 4 digits: '))
thousands = number//1000
hundreds = (number - thousands*1000)//100
decades = (number - thousands*1000 - hundreds*100)//10
digits = number - (thousands*1000 + hundreds*100 + decades*10)
print(digits, decades, hundreds, thousands, sep="")
# Out:
# Enter a number with 4 digits: 1234
# 4321

# %%
number = int(input("4-digit number: "))
thousands = number // 1000
hundreds = (number // 100) % 10
tens = (number // 10) % 10
ones = number % 10
reversed = ones * 1000 + tens * 100 + hundreds * 10 + thousands
print(f"reversed number: {reversed}.")
# Out:
# 4-digit number: 1234
# reversed number: 4321.
